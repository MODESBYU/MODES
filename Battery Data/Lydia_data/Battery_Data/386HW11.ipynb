# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.optimize import curve_fit
from scipy.optimize import fsolve
from scipy.integrate import odeint, quad
from scipy.interpolate import interp1d
from scipy.misc import derivative

# %%
kf = .2
kr = .02
XA = np.linspace(0,.8,1000)
def ra_neg(x):
    return 1/(kf*(2-2*x)*(3-2*x)-kr*2*x)

plt.plot(XA,ra_neg(XA))
plt.ylabel("1/-ra")
plt.xlabel("XA")
# Out:
# Text(0.5, 0, 'XA')

# %%
VR1 = 80*.3*ra_neg(.3)
print("VR1 is",VR1,"L")

XA_2 = np.linspace(.3,.6,1000)
VR2_int = quad(ra_neg,.3,.6)
VR2 = 80*VR2_int[0]
print("VR2 is",VR2,"L")

print("Conversion of CSTR 2 is found by knowing the area from .6 to some conversion multiplied by the flowrate in of A needs to equal 57.1.")
# Out:
# VR1 is 36.36363636363637 L
# VR2 is 57.10525813954433 L
# Conversion of CSTR 2 is found by knowing the area from .6 to some conversion multiplied by the flowrate in of A needs to equal 57.1.
